# %%
import pandas as pd

# %%
# Load dataset
df = pd.read_csv('Heart.csv')
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df= df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# ...

# %%
df['ChestPain']= df['ChestPain'].astype('category')
df['ChestPain']= df['ChestPain'].cat.codes
df['Thal']= df['Thal'].astype('category')
df['Thal']= df['Thal'].cat.codes
df['AHD']= df['AHD'].astype('category')
df['AHD']= df['AHD'].cat.codes
df
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1          3     145   233    1        2    150      0      2.3
# 1     67    1          0     160   286    0        2    108      1      1.5
# 2     67    1          0     120   229    0        2    129      1      2.6
# 3     37    1          1     130   250    0        0    187      0      3.5
# 4     41    0          2     130   204    0        2    172      0      1.4
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 298   45    1          3     110   264    0        0    132      0      1.2
# 299   68    1          0     144   193    1        0    141      0      3.4
# 300   57    1          0     130   131    0        0    115      1      1.2
# 301   57    0          2     130   236    0        2    174      0      0.0
# 302   38    1          1     138   175    0        0    173      0      0.0
#
#      Slope   Ca  Thal  AHD
# 0        3  0.0     0    0
# ...

# %%
df.isnull().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         0
# AHD          0
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1          3     145   233    1        2    150      0      2.3
# 1     67    1          0     160   286    0        2    108      1      1.5
# 2     67    1          0     120   229    0        2    129      1      2.6
# 3     37    1          1     130   250    0        0    187      0      3.5
# 4     41    0          2     130   204    0        2    172      0      1.4
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 297   57    0          0     140   241    0        0    123      1      0.2
# 298   45    1          3     110   264    0        0    132      0      1.2
# 299   68    1          0     144   193    1        0    141      0      3.4
# 300   57    1          0     130   131    0        0    115      1      1.2
# 301   57    0          2     130   236    0        2    174      0      0.0
#
#      Slope   Ca  Thal  AHD
# 0        3  0.0     0    0
# ...

# %%
X_features=df.drop(['AHD'], axis=1)
y_target=df['AHD']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_features,y_target,test_size=0.3,random_state=42)

# %%
x_test
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 283   35    1          2     122   192    0        0    174      0      0.0
# 267   59    1          1     126   218    1        0    134      0      2.2
# 164   48    1          1     124   255    1        0    175      0      0.0
# 9     53    1          0     140   203    1        2    155      1      3.1
# 77    51    0          1     140   308    0        2    142      0      1.5
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 132   29    1          2     130   204    0        2    202      0      0.0
# 72    62    1          0     120   267    0        0     99      1      1.8
# 15    57    1          1     150   168    0        0    174      0      1.6
# 10    57    1          0     140   192    0        0    148      0      0.4
# 157   58    1          0     125   300    0        2    171      0      0.0
#
#      Slope   Ca  Thal
# 283      1  0.0     1
# ...

# %%
x_train
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 226   47    1          0     112   204    0        0    143      0      0.1
# 68    59    1          0     170   326    0        2    140      1      3.4
# 224   63    0          0     108   269    0        0    169      1      1.8
# 37    57    1          0     150   276    0        2    112      1      0.6
# 16    48    1          2     110   229    0        0    168      0      1.0
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 189   69    1          1     140   254    0        2    146      0      2.0
# 71    67    1          0     125   254    1        0    163      0      0.2
# 106   59    1          0     140   177    0        0    162      1      0.0
# 272   46    1          0     140   311    0        0    120      1      1.8
# 102   57    0          0     128   303    0        2    159      0      0.0
#
#      Slope   Ca  Thal
# 226      1  0.0     1
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_sc=scaler.fit_transform(x_train)
x_test_sc=scaler.transform(x_test)

# %%
x_test_sc
# Out:
# array([[-2.1443097 ,  0.69445626,  1.24189912, ..., -0.96525816,
#         -0.70566903, -0.53288606],
#        [ 0.53527611,  0.69445626,  0.19950187, ...,  0.64865348,
#          0.42016934, -2.14699021],
#        [-0.69286739,  0.69445626,  0.19950187, ..., -0.96525816,
#          1.54600772, -0.53288606],
#        ...,
#        [ 0.3119773 ,  0.69445626,  0.19950187, ..., -0.96525816,
#         -0.70566903, -0.53288606],
#        [ 0.3119773 ,  0.69445626, -0.84289539, ...,  0.64865348,
#         -0.70566903, -2.14699021],
#        [ 0.42362671,  0.69445626, -0.84289539, ..., -0.96525816,
#          1.54600772,  1.08121809]])

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
logreg.fit(x_train_sc,y_train)
# Out:
# LogisticRegression()

# %%
y_pred= logreg.predict(x_test_sc)

# %%
logreg.score(x_train_sc,y_train)
# Out:
# 0.8660287081339713

# %%
logreg.score(x_test_sc,y_test)
# Out:
# 0.8

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

accuracy = accuracy_score(y_test, y_pred)
class_report = classification_report(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)


print(f'Accuracy:', accuracy)
print('Confusion Matrix:')
print(conf_matrix)
print("\nClassification Report:\n", class_report)
# Out:
# Accuracy: 0.8
# Confusion Matrix:
# [[43 10]
#  [ 8 29]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.81      0.83        53
#            1       0.74      0.78      0.76        37
#
#     accuracy                           0.80        90
#    macro avg       0.79      0.80      0.80        90
# weighted avg       0.80      0.80      0.80        90

# %%
import seaborn as sns
# confusion matrix sns heatmap
ax = plt.axes()
# Assign the confusion matrix to df_cm
df_cm = conf_matrix  # Use the 'conf_matrix' variable from previous code
sns.heatmap(df_cm, annot=True, annot_kws={"size": 25}, fmt='d',cmap="Blues", ax = ax )
ax.set_title('Confusion Matrix')
plt.show()

# %%
# Create the scatter plot
x=x_test_sc[:,0]
y=y_test
plt.scatter(x, y, cmap='rainbow')



# Set the title and show the plot
plt.title('Scatter Plot of Logistic Regression')
plt.xlabel('facors')
plt.ylabel('AHD')
plt.show()
# Out:
# /tmp/ipykernel_9931/3370350848.py:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, cmap='rainbow')
